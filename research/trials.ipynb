# %%
# %pwd
# Out:
# 'c:\\Users\\user\\OneDrive - University of Waterloo\\Desktop\\Programming Projects\\PulseAI\\research'

# %%
import os
# change the current working directory to the parent directory
os.chdir("../")
# now in the root pulseai directory, so can load in data

# %%
# %pwd
# Out:
# 'c:\\Users\\user\\OneDrive - University of Waterloo\\Desktop\\Programming Projects\\PulseAI'

# %%
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
